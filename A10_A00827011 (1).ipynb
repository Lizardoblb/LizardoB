# %% [markdown]
# ## Final Activity - Rural pop % throughout time

# %%
# %ls
# Out:
#  A10_A00827011.ipynb
#  A5.ipynb
# 'A5_ Visualización con Histogramas & Boxplots (1) (1).ipynb'
#  A6.ipynb
# 'A77 (1).ipynb'
#  antropometria-dataset-1.csv
#  Basicmaths.ipynb
#  Class5.ipynb
#  CreateColumns.ipynb
#  datasets/
#  Graphs.ipynb
# 'pie (1).ipynb'
#  PivotTable2.ipynb
#  PivotTable.ipynb
#  PracticeDataSheet.ipynb
# 'Presentation (2).ipynb'
#  Presentation.ipynb
#  README.md
#  requirements.txt
#  Rural_PopWsheet_A00827011.csv
#  WSActivity2.ipynb

# %%
datafile = 'Rural_PopWsheet_A00827011.csv'

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl

# %%
#pip install seaborn

# %%
#pip install plotly
# Out:
# ...
#      |████████████████████████████████| 27.7 MB 7.5 MB/s
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#pip install statsmodels
# Out:
# ...
#      |████████████████████████████████| 9.8 MB 8.4 MB/s
# ...
#      |████████████████████████████████| 233 kB 36.5 MB/s
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Out:
# ERROR: Could not find a version that satisfies the requirement statsmodel (from versions: none)
# ERROR: No matching distribution found for statsmodel
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
df = pd.read_csv('Rural_PopWsheet_A00827011.csv')
#df

# %%
col = df.columns
#col

# %%
x = col[4:65]
#x

# %%
y = df.iloc[154,4:65]
#y

# %%
import matplotlib.pyplot as plt

# %%
#plt.scatter(x,y)
#plt.show()

# %%
#for number in range(154,155):
#    print(df.iloc[number,0])
#    y2 = df.iloc[number,4:65]
#    graph = plt.figure()
#    graph.set_figwidth(35)
#    graph.set_figheight(5)
#    plt.plot(x,y2)
#    plt.xlabel('Years')
#    plt.ylabel('% of rural Pop')
#    plt.show()

# %%
df.drop(['Country Code','Indicator Name','Indicator Code'],axis = 1, inplace = True)
# In this code, we removed some columns that were useless for making any type of analysis

# %% [markdown]
# # First we will remove the unnecesary columns

# %%
#df

# %%
col2 = df.columns
x2 = col2[1:62]
#x2

# %% [markdown]
# ## In this part, we will place "Country Name" as the index

# %%
df.set_index('Country Name', inplace = True)
#df.head()

# %%
df.loc[['Mexico','United States']]
# Out:
#                  1960    1961    1962    1963    1964    1965    1966    1967  \
# Country Name
# Mexico         49.247  48.410  47.572  46.735  45.900  45.069  44.239  43.413
# United States  30.004  29.623  29.243  28.866  28.492  28.121  27.753  27.388
#
#                  1968    1969  ...    2011    2012    2013    2014    2015  \
# Country Name                   ...
# Mexico         42.589  41.771  ...  21.889  21.595  21.301  21.007  20.715
# United States  27.026  26.667  ...  19.056  18.881  18.701  18.517  18.329
#
#                  2016    2017    2018    2019    2020
# Country Name
# Mexico         20.423  20.133  19.844  19.556  19.269
# United States  18.138  17.942  17.744  17.541  17.336
#
# [2 rows x 61 columns]

# %% [markdown]
# # Description of the Data Sheet

# %% [markdown]
# * This datasheet contains information about the percentage of the rural population in each country from the 1960 to the 2020, including their name and country code.

# %% [markdown]
# * Country : Specifies the name of each country, this being a categorical variable

# %% [markdown]
# * Rows 1960 - 2020 : Represents each years migration percentage, these are numeric variables

# %% [markdown]
# * Link to spreadsheet: https://data.worldbank.org/indicator/SP.RUR.TOTL.ZS?view=chart

# %% [markdown]
# * Data analyzed by the World Bank staff based on the United Nations Population Division's World Urbanization Prospects: 2018 Revision.

# %% [markdown]
# * Questions and observations

# %% [markdown]
# Governments and companies would be very interested in this data because they could estimate the growth and job output required for their countries, governments regarding social issues and needs, and companies could analyze for possible viability due to the city growth.

# %%
df.index
# Out:
# Index(['Aruba', 'Africa Eastern and Southern', 'Afghanistan',
#        'Africa Western and Central', 'Angola', 'Albania', 'Andorra',
#        'Arab World', 'United Arab Emirates', 'Argentina',
#        ...
#        'Virgin Islands (U.S.)', 'Vietnam', 'Vanuatu', 'World', 'Samoa',
#        'Kosovo', 'Yemen, Rep.', 'South Africa', 'Zambia', 'Zimbabwe'],
#       dtype='object', name='Country Name', length=266)

# %% [markdown]
# # Hows the similarity in migration to urban areas between Mexico and the United States?

# %%
#print(df.loc['Mexico'])
graph = plt.figure()
graph.set_figwidth(35)
graph.set_figheight(5)
plt.plot(df.loc['Mexico','1960':'2020'])
plt.xlabel('Years', fontsize = 23)
plt.xticks( fontsize = 11)
plt.ylabel('% of rural Pop', fontsize = 17)
plt.yticks( fontsize = 15)
plt.title('Mexico', fontsize = 30)
plt.show()
graph = plt.figure()
graph.set_figwidth(35)
graph.set_figheight(5)
plt.plot(df.loc['United States','1960':'2020'])
plt.xlabel('Years', fontsize = 23)
plt.xticks( fontsize = 11)
plt.ylabel('% of rural Pop', fontsize = 17)
plt.yticks( fontsize = 15)
plt.title('United States', fontsize = 30)
plt.show()

# %% [markdown]
# * For this first question we will analyze how Mexico and its northern neighbor look like in terms of rural pop percentage.
#   We can observe that in 1960, Mexico has a 50% rural pop and the US has a 30%, till this day the percentage is pretty most the same,
#   leaving Mexico in 2020 with a 19.263% and the US with a 17.3%.

# %% [markdown]
# # Now that we made this comparison, how does the migration looks in North America?

# %%
graph = plt.figure()
graph.set_figwidth(35)
graph.set_figheight(5)
plt.plot(df.loc[['Mexico','United States','Canada'], '1980':].transpose())
plt.xlabel('Years', fontsize = 23)
plt.xticks( fontsize = 17)
plt.ylabel('% of rural Pop', fontsize = 17)
plt.yticks( fontsize = 15)
plt.title('Mexico, United States and Canada', fontsize = 30)
plt.show()

# %% [markdown]
# * We can observe that even though Mexico had a pretty high % of rural pop in the 80's, nowadays the percentage overall is pretty tight, meaning that most people in North America have been in constant migration since the 80's we will now take a closer look to visualize hows the percentage of the recent years

# %%
graph = plt.figure()
graph.set_figwidth(15)
graph.set_figheight(5)
plt.plot(df.loc[['Mexico','United States','Canada'], '2015':].transpose())
plt.xlabel('Years', fontsize = 23)
plt.xticks( fontsize = 17)
plt.ylabel('% of rural Pop', fontsize = 17)
plt.yticks( fontsize = 15)
plt.title('Mexico, United States and Canada', fontsize = 30)
plt.show()

# %% [markdown]
# * Taking a closer look we can assume that theres only a ~2% difference between rural pop between these countries

# %% [markdown]
# # How does the pie chart of 2020 looks like?

# %%
df['1980'].plot(kind = 'pie')

# %% [markdown]
# # How has the migration from rural to urban pop changed in Mexico in the last 15 years?

# %%
graph = plt.figure()
graph.set_figwidth(35)
graph.set_figheight(5)
plt.plot(df.loc['Mexico','2005':'2020'])
plt.xlabel('Years', fontsize = 23)
plt.xticks( fontsize = 17)
plt.ylabel('% of rural Pop', fontsize = 17)
plt.yticks( fontsize = 15)
plt.title('Mexico', fontsize = 30)
plt.show()

# %% [markdown]
# * After analyzing last graphs, i noticed that Mexico had a decently decadent line in terms of its rural poulation, so with this information
#   from 2015 till today, we can assume that the rural pop % goes down aproximately 0.333% per year, making this a useful forecast for possible
#   companies in rural or urban por areas

# %% [markdown]
# # Whats the country with the largest and smallest rural pop so far?

# %%
#df.sort_values(by='2020', ascending=True)
#df

# %%
graph = plt.figure()
graph.set_figwidth(35)
graph.set_figheight(5)
plt.plot(df.loc[['Papua New Guinea','Kuwait'],'1960':'2020'].transpose())
plt.xlabel('Years', fontsize = 23)
plt.ylabel('% of rural Pop', fontsize = 17)
plt.yticks( fontsize = 15)
plt.title('Papua New Guinea vs Kuwait', fontsize = 30)
plt.show()

# %% [markdown]
# * After arranging the data, we can now visualize the country that has the most rural population, being this one Papua New Guinea. On the other side, having the country with least rural pop, being one of these ones Kuwait, given the fact of the size of the country and its city, or maybe some data missing regarding the census.

# %% [markdown]
# # We will now analyze the most frequent percentage of rural population in 2020

# %%
graph = plt.figure()
graph.set_figwidth(25)
graph.set_figheight(5)
df['2020'].plot(kind='hist')
plt.title('2020s most frequent percentages', fontsize = 30)
plt.style.use('seaborn-pastel')
plt.yticks( fontsize = 20)
plt.xticks( fontsize = 20)

plt.show()

# %% [markdown]
# * With this information we can assume that the most common percentage amongst countries varies between 17% ~ 24%, having a total of 35 countries in this category, we can also observe that not many countries have more than 80% of its rural population

# %% [markdown]
# # By using boxplot, how does the rural pop % behaves through time?

# %%
plt.subplot(2,2,1)
sns.boxplot(data = df.loc[:,['1980']])
sns.set(rc={'figure.figsize':(15,15)})
plt.subplot(2,2,2)
sns.boxplot(data = df.loc[:,['2000']])
plt.subplot(2,2,3)
sns.boxplot(data = df.loc[:,['2020']])
plt.subplot(2,2,4)
sns.boxplot(data = df.loc[:,['1980','2000','2020']])

# %% [markdown]
# * We can observe how the median from these three years slowly shift towards a low popuation, it shows how the rural population in the world slowly migrates to other cities

# %%
y = pd.DataFrame(df['1980'])
x = pd.DataFrame(df['1980'])
lm = linear_model.LinearRegression()
model_lm = lm.fit(x,y)
model_lm
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_168/3750272441.py in <module>
#       1 y = pd.DataFrame(df['1980'])
#       2 x = pd.DataFrame(df['1980'])
# ----> 3 lm = linear_model.LinearRegression()
#       4 model_lm = lm.fit(x,y)
#       5 model_lm
#
# NameError: name 'linear_model' is not defined
