# %%
# %ls
# Out:
# Basicmaths.ipynb         README.md         Rural_PopWsheet_A00827011.csv
# datasets/                requirements.txt  RuralPopWS.ipynb
# PracticeDataSheet.ipynb  RpWsD1.ipynb      Untitled.ipynb

# %%
datafile = 'Rural_PopWsheet_A00827011.csv'

# %%
import pandas as pd

# %%
df = pd.read_csv('Rural_PopWsheet_A00827011.csv')
df
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                                Indicator Name  Indicator Code       1960  \
# 0    Rural population (% of total population)  SP.RUR.TOTL.ZS  49.224000
# 1    Rural population (% of total population)  SP.RUR.TOTL.ZS  85.295312
# 2    Rural population (% of total population)  SP.RUR.TOTL.ZS  91.599000
# 3    Rural population (% of total population)  SP.RUR.TOTL.ZS  85.329671
# ...

# %%
col = df.columns
col
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020'],
#       dtype='object')

# %%
x = col[4:65]
x
# Out:
# Index(['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020'],
#       dtype='object')

# %%
y = df.iloc[154,4:65]
y
# Out:
# 1960    49.247
# 1961     48.41
# 1962    47.572
# 1963    46.735
# 1964      45.9
#          ...
# 2016    20.423
# 2017    20.133
# 2018    19.844
# 2019    19.556
# 2020    19.269
# Name: 154, Length: 61, dtype: object

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x,y)
plt.show()

# %%
for number in range(154,155):
    print(df.iloc[number,0])
    y2 = df.iloc[number,4:65]
    graph = plt.figure()
    graph.set_figwidth(35)
    graph.set_figheight(5)
    plt.plot(x,y2)
    plt.xlabel('Years')
    plt.ylabel('% of rural Pop')
    plt.show()
# Out:
# Mexico

# %%
df.drop(['Country Code','Indicator Name','Indicator Code'],axis = 1, inplace = True)
# In this code, we removed some columns that were useless for making any type of analysis

# %%
df
# Out:
#                     Country Name       1960       1961       1962       1963  \
# 0                          Aruba  49.224000  49.239000  49.254000  49.270000
# 1    Africa Eastern and Southern  85.295312  85.055541  84.814392  84.555586
# 2                    Afghanistan  91.599000  91.316000  91.024000  90.724000
# 3     Africa Western and Central  85.329671  84.946423  84.550718  84.135979
# 4                         Angola  89.565000  89.202000  88.796000  88.376000
# ..                           ...        ...        ...        ...        ...
# 261                       Kosovo        NaN        NaN        NaN        NaN
# 262                  Yemen, Rep.  90.900000  90.541000  90.169000  89.784000
# 263                 South Africa  53.381000  53.207000  53.094000  52.980000
# 264                       Zambia  81.855000  81.049000  80.215000  79.288000
# 265                     Zimbabwe  87.392000  87.179000  86.918000  86.422000
#
# ...

# %%
col2 = df.columns
x2 = col2[1:62]
x2
# Out:
# Index(['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020'],
#       dtype='object')

# %%
for number in range(153,155):
    print(df.iloc[number,0])
    y2 = df.iloc[number,1:62]
    graph = plt.figure()
    graph.set_figwidth(35)
    graph.set_figheight(5)
    plt.plot(x2,y2)
    plt.xlabel('Years')
    plt.ylabel('% of rural Pop')
    plt.show()
#In this code we are plotting the % of rural pop across time, based on the id number of each country
# Out:
# Middle East & North Africa
# Mexico

# %%
df.set_index('Country Name', inplace = True)
df.head()
# Out:
#                                   1960       1961       1962       1963  \
# Country Name
# Aruba                        49.224000  49.239000  49.254000  49.270000
# Africa Eastern and Southern  85.295312  85.055541  84.814392  84.555586
# Afghanistan                  91.599000  91.316000  91.024000  90.724000
# Africa Western and Central   85.329671  84.946423  84.550718  84.135979
# Angola                       89.565000  89.202000  88.796000  88.376000
#
#                                   1964       1965       1966       1967  \
# Country Name
# Aruba                        49.285000  49.300000  49.315000  49.330000
# Africa Eastern and Southern  84.280924  83.998008  83.706262  83.408722
# Afghanistan                  90.414000  90.096000  89.767000  89.430000
# Africa Western and Central   83.705016  83.258639  82.833184  82.394543
# Angola                       87.942000  87.496000  87.035000  86.559000
#
# ...

# %%
df.loc[['Mexico','Angola']]
# Out:
#                 1960    1961    1962    1963    1964    1965    1966    1967  \
# Country Name
# Mexico        49.247  48.410  47.572  46.735  45.900  45.069  44.239  43.413
# Angola        89.565  89.202  88.796  88.376  87.942  87.496  87.035  86.559
#
#                 1968    1969  ...    2011    2012    2013    2014    2015  \
# Country Name                  ...
# Mexico        42.589  41.771  ...  21.889  21.595  21.301  21.007  20.715
# Angola        86.068  85.564  ...  39.472  38.732  37.998  37.269  36.554
#
#                 2016    2017    2018    2019    2020
# Country Name
# Mexico        20.423  20.133  19.844  19.556  19.269
# Angola        35.851  35.161  34.486  33.823  33.175
#
# [2 rows x 61 columns]

# %% [markdown]
# # Description of the Data Sheet

# %% [markdown]
# * This datasheet contains information about the percentage of the rural population in each country from the 1960 to the 2020, including their name and country code.

# %% [markdown]
# * Country : Specifies the name of each country

# %% [markdown]
# * Rows 1960 - 2020 : Represents each years migration percentage

# %% [markdown]
# * Link to spreadsheet: https://data.worldbank.org/indicator/SP.RUR.TOTL.ZS?view=chart

# %% [markdown]
# * Data analyzed by the World Bank staff based on the United Nations Population Division's World Urbanization Prospects: 2018 Revision.

# %% [markdown]
# * Questions

# %% [markdown]
#     1.- What year had the biggest percentage of migration to urban areas?
#     2.- Whats the city with the lowest urban percentage in the year x ?
#     3.- What country had the biggest migration percentage overall?
#     4.- What countries have their urban population percentage over/under x ?
#     5.- In what year did x had the biggest migration percentage/increment to urban areas?

# %% [markdown]
# Governments and companies would be very interested in this data because they could estimate the growth and job output required for their countries, governments regarding social issues and needs, and companies could analyze for possible viability due to the city growth.
