# %%
import pandas as pd

# %%
import numpy as np

# %%
# %ls datasets/'census.csv'
# Out:
# datasets/census.csv

# %%
df = pd.read_csv('datasets/census.csv')

# %%
df.head(2)
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  ...  RDOMESTICMIG2011  \
# 0        4779736            4780127          4785161  ...          0.002295
# 1          54571              54571            54660  ...          7.242091
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# 0         -0.193196          0.381066          0.582002         -0.467369
# 1         -2.915927         -3.012349          2.265971         -2.530799
#
#    RNETMIG2011  RNETMIG2012  RNETMIG2013  RNETMIG2014  RNETMIG2015
# 0     1.030015     0.826644     1.383282     1.724718     0.712594
# 1     7.606016    -2.626146    -2.722002     2.592270    -2.187333
#
# [2 rows x 100 columns]

# %%
df.describe()
# Out:
#             SUMLEV       REGION     DIVISION        STATE       COUNTY  \
# count  3193.000000  3193.000000  3193.000000  3193.000000  3193.000000
# mean     49.840276     2.668650     5.191356    30.259004   101.918572
# std       1.253884     0.807513     1.973991    15.153897   107.626583
# min      40.000000     1.000000     1.000000     1.000000     0.000000
# 25%      50.000000     2.000000     4.000000    18.000000    33.000000
# 50%      50.000000     3.000000     5.000000    29.000000    77.000000
# 75%      50.000000     3.000000     7.000000    45.000000   133.000000
# max      50.000000     4.000000     9.000000    56.000000   840.000000
#
#        CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  \
# count   3.193000e+03       3.193000e+03     3.193000e+03     3.193000e+03
# mean    1.933871e+05       1.933969e+05     1.937657e+05     1.952514e+05
# std     1.176201e+06       1.176244e+06     1.178710e+06     1.189648e+06
# ...

# %%
x = df.columns.tolist()
x.sort()

# %%
pd.pivot_table(df,
               index = 'STNAME',
               aggfunc = ['mean','median'],
               values = 'BIRTHS2010',
               margins = True,
               columns = 'SUMLEV'
              )
# Out:
#                                mean                              median  \
# SUMLEV                           40           50          All        40
# STNAME
# Alabama                14226.000000   212.328358   418.411765   14226.0
# Alaska                  2892.000000    99.724138   192.800000    2892.0
# Arizona                20937.000000  1395.800000  2617.125000   20937.0
# Arkansas                9439.000000   125.853333   248.394737    9439.0
# California            123324.000000  2126.275862  4180.474576  123324.0
# Colorado               16791.000000   262.359375   516.646154   16791.0
# Connecticut             9489.000000  1186.125000  2108.666667    9489.0
# Delaware                2847.000000   949.000000  1423.500000    2847.0
# District of Columbia    2243.000000  2243.000000  2243.000000    2243.0
# Florida                50872.000000   759.283582  1496.235294   50872.0
# Georgia                32489.000000   204.333333   406.112500   32489.0
# ...
